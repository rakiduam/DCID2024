# %% [markdown]
# <a href="https://colab.research.google.com/github/rakiduam/DCID2024/blob/main/ProyectoFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
from osgeo import gdal
import matplotlib.pyplot as plt

# %% [markdown]
# ## listado de imagenes

# %%
os.chdir('/content/drive/MyDrive/')


lst_img = os.listdir('/content/drive/MyDrive/GEE_DATA')
lst_img[0:5]
# Out:
# ['L8_2020-2021_11_feb-0000000000-0000000000.tif',
#  'L8_2020-2021_11_feb-0000000000-0000004096.tif',
#  'L8_2020-2021_11_feb-0000004096-0000000000.tif',
#  'L8_2020-2021_11_feb-0000004096-0000004096.tif',
#  'L8_2020-2021_12_mar-0000000000-0000000000.tif']

# %% [markdown]
# # BANDAS o arrays contenidos en la imagen
# bands: List (14 elements)
#
#
# *   0: __"BLUE"__, double ∈ [-0.2, 1.6022125], EPSG:4326
# *   1: __"GREEN"__, double ∈ [-0.2, 1.6022125], EPSG:4326
# *   2: __"RED"__, double ∈ [-0.2, 1.6022125], EPSG:4326
# *   3: __"NIR"__, double ∈ [-0.2, 1.6022125], EPSG:4326
# *   4: __"SWIR1"__, double ∈ [-0.2, 1.6022125], EPSG:4326
# *   5: __"SWIR2"__, double ∈ [-0.2, 1.6022125], EPSG:4326
# *   6: __"NDVI"__, double ∈ [-1.0, 1.0], EPSG:4326
# *   7: __"EVI"__, double ∈ [-1.0, 1.0], EPSG:4326
# *   8: __"NDMI"__, double ∈ [-1.0, 1.0], EPSG:4326
# *   9 __"MSI"__, double ∈ [-1.0, 1.0], EPSG:4326
# *   10: __"MSAVI"__, double ∈ [-1.0, 1.0], EPSG:4326
# *   11: __"MBSI"__, double, EPSG:4326 __*no normalizado*__
# *   12: __"NSDS"__, double, EPSG:4326 __*no normalizado*__
# *   13: __"GRAYSCALE"__ , double, EPSG:4326 __*no normalizado*__
#
#
# __EPSG:4326__ corresponde al sistema de coordenadas de las imagenes, en este caso es en grados sexagesimales, o también conocida como geograficas.

# %%
ds = gdal.Open('/content/drive/MyDrive/GEE_DATA/' + lst_img[0]) # esta imagen pesa alrededor de 2Gb
image_array = ds.ReadAsArray()
#print(image_array)

# %%
plt.imshow(np.transpose(image_array[:3,:,:], (2, 1, 0)),vmin=0, vmax=0.02)  # Select first 3 bands (RGB) and transpose for display
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# la imagen anterior deberia verse algo como esto
